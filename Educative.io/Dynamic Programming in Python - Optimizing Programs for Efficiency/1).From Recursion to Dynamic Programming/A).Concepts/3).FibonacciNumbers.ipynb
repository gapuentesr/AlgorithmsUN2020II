# %% [markdown]
# <h1>The Fibonacci Numbers</h1>
# Implementation of Fibonacci numbers

# %%
def fib(n):
  if n == 0: # base case 1
    return 0
  if n == 1: # base case 2
    return 1
  else: # recursive step
    return fib(n-1) + fib(n-2)

print (fib(10))
# Out:
# 55
